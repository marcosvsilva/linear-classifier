# %%
# %config Completer.use_jedi = False

# %%
import pandas as pd
import seaborn as sns
from datetime import datetime
import numpy as np
from sklearn.metrics import accuracy_score
from sklearn.dummy import DummyClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.svm import LinearSVC, SVC

# %%
SEED = 5
np.random.seed(SEED)

# %%
data = pd.read_csv("https://gist.githubusercontent.com/guilhermesilveira/4d1d4a16ccbf6ea4e0a64a38a24ec884/raw/afd05cb0c796d18f3f5a6537053ded308ba94bf7/car-prices.csv")
data.head()
# Out:
#    Unnamed: 0  mileage_per_year  model_year      price sold
# 0           0             21801        2000   30941.02  yes
# 1           1              7843        1998   40557.96  yes
# 2           2              7109        2006   89627.50   no
# 3           3             26823        2015   95276.14   no
# 4           4              7935        2014  117384.68  yes

# %%
current_year = datetime.today().year
current_year
# Out:
# 2023

# %%
data["age"] = current_year - data.model_year
data["target"] = [1 if x == "yes" else 0 for x in data.sold]
data = data.drop(["sold", "model_year"], axis=1)

columns = [col for col in data.columns if col != "target"]
x = data[columns]
y = data["target"]

data = data.iloc[: , 1:]
data
# Out:
#       mileage_per_year      price  age  target
# 0                21801   30941.02   23       1
# 1                 7843   40557.96   25       1
# 2                 7109   89627.50   17       0
# 3                26823   95276.14    8       0
# 4                 7935  117384.68    9       1
# ...                ...        ...  ...     ...
# 9995             15572   97112.86   17       0
# 9996             13246  107424.63   21       1
# 9997             13018   93856.99    9       0
# 9998             10464   51250.57   12       1
# 9999             12362   87945.73   24       0
#
# [10000 rows x 4 columns]

# %%
sns.scatterplot(data.mileage_per_year, data.price, hue=y)
# Out:
# <AxesSubplot:xlabel='mileage_per_year', ylabel='price'>

# %%
sns.scatterplot(data.age, data.price, hue=y)
# Out:
# <AxesSubplot:xlabel='age', ylabel='price'>

# %%
y.value_counts()
# Out:
# 1    5800
# 0    4200
# Name: target, dtype: int64

# %%
baseline = np.ones(y.shape)
baseline.shape
# Out:
# (10000,)

# %%
acc = accuracy_score(baseline, y)
print(acc)
# Out:
# 0.58

# %%
train_x, test_x, train_y, test_y = train_test_split(x, y, test_size=.25, stratify=y)

# %%
dummy = DummyClassifier(strategy='stratified')
dummy.fit(train_x, train_y)

pred = dummy.score(test_x, test_y)
print(acc)
# Out:
# 0.58

# %%
dummy = DummyClassifier(strategy='most_frequent')
dummy.fit(train_x, train_y)

pred = dummy.score(test_x, test_y)
print(acc)
# Out:
# 0.58

# %% [markdown]
# ### testing models

# %%
model = LinearSVC()
model.fit(train_x, train_y)

acc = model.score(test_x, test_y)
print(acc)
# Out:
# 0.5504
# /home/marcos/anaconda3/envs/classify/lib/python3.6/site-packages/sklearn/svm/_base.py:986: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)

# %%
scaler = StandardScaler()
scaler.fit(train_x)

train_x = scaler.transform(train_x)
test_x = scaler.transform(test_x)

# %%
model = SVC()
model.fit(train_x, train_y)

acc = model.score(test_x, test_y)
print(acc)
# Out:
# 0.7756
